# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %%
pd.set_option("display.max_columns", None)
df = pd.read_csv('val_stats.csv', low_memory = False)
df
# Out:
#       region            name     tag      rating  damage_round headshots  \
# 0        NaN        ShimmyXD    #NA1     Radiant         135.8       992
# 1        NaN       XSET Cryo  #cells     Radiant         170.3       879
# 2        NaN   PuRelittleone  #yoruW     Radiant         147.5       720
# 3        NaN            Boba   #0068     Radiant         178.2       856
# 4        NaN     i love mina  #kelly     Radiant         149.8       534
# ...      ...             ...     ...         ...           ...       ...
# 85673    LAT        Kazutora  #img0d     Radiant         138.2       342
# 85674    LAT  el lobo marino  #uthur     Radiant         182.9       650
# 85675    LAT          p9pzet   #666x     Radiant         158.8       613
# 85676    LAT  EZ4TGD EnSBuwu  #kmeve  Immortal 3         155.9       132
# 85677    LAT            Neon    #SSJ     Radiant         164.4     1,127
#
#        headshot_percent  aces  clutches  flawless first_bloods  kills deaths  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85678 entries, 0 to 85677
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   region            64813 non-null  object
#  1   name              85675 non-null  object
#  2   tag               85358 non-null  object
#  3   rating            85678 non-null  object
#  4   damage_round      85678 non-null  float64
#  5   headshots         85678 non-null  object
#  6   headshot_percent  85678 non-null  float64
#  7   aces              85678 non-null  int64
#  8   clutches          85678 non-null  int64
#  9   flawless          85678 non-null  int64
#  10  first_bloods      85678 non-null  object
#  11  kills             85678 non-null  object
#  12  deaths            85678 non-null  object
#  13  assists           85678 non-null  object
#  14  kd_ratio          85678 non-null  float64
#  15  kills_round       85678 non-null  float64
# ...

# %%
x = df[['gun3_kills', 'gun2_kills', 'gun1_kills', 'wins', 'most_kills', 'flawless', 'aces', 'headshots']]
y = df[['clutches']]

# %%
x
# Out:
#        gun3_kills gun2_kills gun1_kills  wins  most_kills  flawless  aces  \
# 0             147        220        802    59          29        80     0
# 1             137        226        689    52          32        94     2
# 2             102        231        444    42          39        59     3
# 3              36         48        754    32          37        49     3
# 4              64         65        419    32          29        38     2
# ...           ...        ...        ...   ...         ...       ...   ...
# 85673          71        175        190    32          24        54     0
# 85674         139        212        400    32          32        42     4
# 85675          87        159        373    26          33        54     0
# 85676          17         37         89     8          27        18     0
# 85677         108        132        939    49          40        82     3
#
#       headshots
# 0           992
# 1           879
# 2           720
# ...

# %%
x.isnull().sum()
# Out:
# gun3_kills    0
# gun2_kills    0
# gun1_kills    0
# wins          0
# most_kills    0
# flawless      0
# aces          0
# headshots     0
# dtype: int64

# %%
x.dtypes
# Out:
# gun3_kills     int64
# gun2_kills    object
# gun1_kills    object
# wins           int64
# most_kills     int64
# flawless       int64
# aces           int64
# headshots     object
# dtype: object

# %%
LE = preprocessing.LabelEncoder()
x['gun1_kills'] = LE.fit_transform(x['gun1_kills'])
x['gun2_kills'] = LE.fit_transform(x['gun2_kills'])
x['headshots'] = LE.fit_transform(x['headshots'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
x.dtypes
# Out:
# gun3_kills    int64
# gun2_kills    int64
# gun1_kills    int64
# wins          int64
# most_kills    int64
# flawless      int64
# aces          int64
# headshots     int64
# dtype: object

# %%
y
# Out:
#        clutches
# 0           140
# 1           122
# 2           117
# 3            83
# 4            71
# ...         ...
# 85673        58
# 85674        77
# 85675        70
# 85676        23
# 85677       136
#
# [85678 rows x 1 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 40)

# %%
rf_reg = RandomForestRegressor()
rf_reg.fit(x_train, y_train)
rf_predict = rf_reg.predict(x_test)
rf_acc = r2_score(y_test, rf_predict)
print("Accuracy: ", rf_acc)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Accuracy:  0.9507284486789309
